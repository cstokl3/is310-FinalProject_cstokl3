# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import matplotlib_inline
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
# Creating list to append tweet data to
tweets_list_java = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('java AND programming since:2012-01-01 until:2022-01-01').get_items()):
    tweets_list_java.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df_java = pd.DataFrame(tweets_list_java, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df_java.to_csv('java.csv')

# %%
tweets_df_java.sort_values(by='Datetime')
# Out:
#                         Datetime             Tweet Id  \
# 183540 2012-01-01 00:31:34+00:00   153272114328240128
# 183539 2012-01-01 01:49:18+00:00   153291677124136960
# 183538 2012-01-01 03:33:31+00:00   153317905747017728
# 183537 2012-01-01 03:34:44+00:00   153318209079095298
# 183536 2012-01-01 03:58:13+00:00   153324119302221824
# ...                          ...                  ...
# 4      2021-12-31 18:30:41+00:00  1476984169129336833
# 3      2021-12-31 19:11:29+00:00  1476994437444419585
# 2      2021-12-31 20:06:23+00:00  1477008250658856961
# 1      2021-12-31 20:15:00+00:00  1477010419852070913
# 0      2021-12-31 22:16:41+00:00  1477041041446473728
#
#                                                      Text         Username  \
# 183540  Introduction to Java Programming: Y Daniel Lia...          us_java
# 183539  Introduction to Java Programming, Comprehensiv...        RubySquad
# 183538  Java Programming: Introductory 8211 Joyce Farr...       mayomiichb
# ...

# %%
tweets_df_java.drop('count', inplace=True, axis=1)

# %%
tweets_df_java
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-12-31 22:16:41+00:00  1477041041446473728
# 1      2021-12-31 20:15:00+00:00  1477010419852070913
# 2      2021-12-31 20:06:23+00:00  1477008250658856961
# 3      2021-12-31 19:11:29+00:00  1476994437444419585
# 4      2021-12-31 18:30:41+00:00  1476984169129336833
# ...                          ...                  ...
# 183536 2012-01-01 03:58:13+00:00   153324119302221824
# 183537 2012-01-01 03:34:44+00:00   153318209079095298
# 183538 2012-01-01 03:33:31+00:00   153317905747017728
# 183539 2012-01-01 01:49:18+00:00   153291677124136960
# 183540 2012-01-01 00:31:34+00:00   153272114328240128
#
#                                                      Text         Username
# 0       I just published "Java Tutorial. Functions" ht...  DeveloperYester
# 1       Day 84: Once the Salesman's Travel app version...        rclarkecf
# 2       Tried to crosspost#100Daysofcode #javascript #...  programmerjoke9
# ...

# %%
# %matplotlib inline

tweets_df_java['Datetime'].value_counts().plot()
# Out:
# <AxesSubplot:>
